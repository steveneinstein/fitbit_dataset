# %%
import pandas as pd

# %%
df = pd.read_csv('FitBit data.csv')

# %%
df.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
for i in df:
    print(i)
# Out:
# Id
# ActivityDate
# TotalSteps
# TotalDistance
# TrackerDistance
# LoggedActivitiesDistance
# VeryActiveDistance
# ModeratelyActiveDistance
# LightActiveDistance
# SedentaryActiveDistance
# VeryActiveMinutes
# FairlyActiveMinutes
# LightlyActiveMinutes
# SedentaryMinutes
# Calories

# %%
df.columns
# Out:
# Index(['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
#        'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories'],
#       dtype='object')

# %%
df['ActivityDate'] = pd.to_datetime(df['ActivityDate'],format = '%m/%d/%Y')

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366   2016-03-25       11004       7.110000         7.110000
# 1    1503960366   2016-03-26       17609      11.550000        11.550000
# 2    1503960366   2016-03-27       12736       8.530000         8.530000
# 3    1503960366   2016-03-28       13231       8.930000         8.930000
# 4    1503960366   2016-03-29       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391   2016-04-08       23014      20.389999        20.389999
# 453  8877689391   2016-04-09       16470       8.070000         8.070000
# 454  8877689391   2016-04-10       28497      27.530001        27.530001
# 455  8877689391   2016-04-11       10622       8.060000         8.060000
# 456  8877689391   2016-04-12        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %% [markdown]
# # Q2 : How many unique ID's are present

# %%
df.columns
# Out:
# Index(['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
#        'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories'],
#       dtype='object')

# %%
len(df['Id'].unique())
# Out:
# 35

# %% [markdown]
# # Q3 : Which ID is one of active ID that you have in whole data set

# %%
df.head(3)
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366   2016-03-25       11004           7.11             7.11
# 1  1503960366   2016-03-26       17609          11.55            11.55
# 2  1503960366   2016-03-27       12736           8.53             8.53
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 4.07                      0.0                 33
# 1                 3.91                      0.0                 89
# 2                 3.71                      0.0                 56
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# ...

# %%
df['VeryActiveMinutes'].max()
# Out:
# 202

# %%
len(df)
# Out:
# 457

# %%
df.groupby(['Id']).sum()[['VeryActiveMinutes']].idxmax(),df.groupby(['Id']).sum()[['VeryActiveMinutes']].max()
# Out:
# (VeryActiveMinutes    8053475328
#  dtype: int64,
#  VeryActiveMinutes    933
#  dtype: int64)

# %% [markdown]
# # Q4 :How many of them have not logged there activity find out interms of number of ID's

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10496/964094849.py in <module>
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
len(df[df['LoggedActivitiesDistance'] == 0]['Id'].unique())
# Out:
# 35

# %% [markdown]
# # Q5 :Find out who is the laziest person ID that we have in data set

# %%
df.columns
# Out:
# Index(['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
#        'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories'],
#       dtype='object')

# %%
df['TotalSteps'].max()
# Out:
# 28497

# %%
df.groupby(['Id']).sum()[['Calories']].idxmin(),df.groupby(['Id']).sum()[['Calories']].min()
# Out:
# (Calories    4388161847
#  dtype: int64,
#  Calories    14442
#  dtype: int64)

# %% [markdown]
# # Q6 : How many healthy persons we have in our Data Set

# %%
def check_healthy(var):
    min_cal_burn = 2500
    if var >= 2500:
        return 'Healthy'
    else:
        return 'Unhealthy'

# %%
df.columns
# Out:
# Index(['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
#        'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories'],
#       dtype='object')

# %%
len(df[df['Calories'] >= 2500]['Id'].unique())
# Out:
# 17

# %% [markdown]
# # Q7 : How many person are not a regular person with respect to activity

# %%
df.head(10)
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366   2016-03-25       11004           7.11             7.11
# 1  1503960366   2016-03-26       17609          11.55            11.55
# 2  1503960366   2016-03-27       12736           8.53             8.53
# 3  1503960366   2016-03-28       13231           8.93             8.93
# 4  1503960366   2016-03-29       12041           7.85             7.85
# 5  1503960366   2016-03-30       10970           7.16             7.16
# 6  1503960366   2016-03-31       12256           7.86             7.86
# 7  1503960366   2016-04-01       12262           7.87             7.87
# 8  1503960366   2016-04-02       11248           7.25             7.25
# 9  1503960366   2016-04-03       10016           6.37             6.37
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# ...

# %%
df.columns
# Out:
# Index(['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
#        'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories'],
#       dtype='object')

# %%
df.head(20)
# Out:
#             Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0   1503960366   2016-03-25       11004           7.11             7.11
# 1   1503960366   2016-03-26       17609          11.55            11.55
# 2   1503960366   2016-03-27       12736           8.53             8.53
# 3   1503960366   2016-03-28       13231           8.93             8.93
# 4   1503960366   2016-03-29       12041           7.85             7.85
# 5   1503960366   2016-03-30       10970           7.16             7.16
# 6   1503960366   2016-03-31       12256           7.86             7.86
# 7   1503960366   2016-04-01       12262           7.87             7.87
# 8   1503960366   2016-04-02       11248           7.25             7.25
# 9   1503960366   2016-04-03       10016           6.37             6.37
# 10  1503960366   2016-04-04       14557           9.80             9.80
# 11  1503960366   2016-04-05       14844           9.73             9.73
# ...

# %%
df['Id'].value_counts().min()
# Out:
# 8

# %%
df[['Id']].value_counts()
# Out:
# Id
# 4057192912    32
# 4020332650    32
# 1503960366    19
# 1624580081    19
# 2347167796    15
# 4702921684    15
# 4445114986    15
# 6962181067    14
# 2320127002    12
# 4558609924    12
# 8792009665    12
# 8378563200    12
# 8253242879    12
# 7086361926    12
# 7007744171    12
# 2026352035    12
# 5553957443    12
# 8877689391    12
# 1844505072    12
# 2022484408    12
# 2873212765    12
# 3977333714    12
# 1927972279    12
# 4319703577    12
# 8053475328    11
# 5577150313    11
# 6290855005    10
# 1644430081    10
# 6117666160    10
# 3372868164    10
# 6391747486     9
# 6775888955     9
# 2891001357     8
# 8583815059     8
# 4388161847     8
# dtype: int64

# %%
for i in df['Id'].unique():
    if len(df[df['Id'] == i]) == df[['Id']].value_counts().min():
        print (i)
# Out:
# 2891001357
# 4388161847
# 8583815059

# %%
df[['Id']].value_counts().min()
# Out:
# 8

# %%
df[df['Calories'] ==1819 ]
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 4.07                      0.0                 33
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                   12                   205               804      1819

# %%
list(df['Id'].unique())
# Out:
# [1503960366,
#  1624580081,
#  1644430081,
#  1844505072,
#  1927972279,
#  2022484408,
#  2026352035,
#  2320127002,
#  2347167796,
#  2873212765,
#  2891001357,
#  3372868164,
#  3977333714,
#  4020332650,
#  4057192912,
#  4319703577,
#  4388161847,
#  4445114986,
#  4558609924,
#  4702921684,
#  5553957443,
#  5577150313,
#  6117666160,
#  6290855005,
#  6391747486,
#  6775888955,
#  6962181067,
#  7007744171,
#  7086361926,
#  8053475328,
#  8253242879,
#  8378563200,
#  8583815059,
#  8792009665,
#  8877689391]

# %%
df[df['Id'] == 4057192912].count()
# Out:
# Id                          32
# ActivityDate                32
# TotalSteps                  32
# TotalDistance               32
# TrackerDistance             32
# LoggedActivitiesDistance    32
# VeryActiveDistance          32
# ModeratelyActiveDistance    32
# LightActiveDistance         32
# SedentaryActiveDistance     32
# VeryActiveMinutes           32
# FairlyActiveMinutes         32
# LightlyActiveMinutes        32
# SedentaryMinutes            32
# Calories                    32
# dtype: int64

# %%
df['Id']
# Out:
# 0      1503960366
# 1      1503960366
# 2      1503960366
# 3      1503960366
# 4      1503960366
#           ...
# 452    8877689391
# 453    8877689391
# 454    8877689391
# 455    8877689391
# 456    8877689391
# Name: Id, Length: 457, dtype: int64

# %%
list(df['Id'].unique())
# Out:
# [1503960366,
#  1624580081,
#  1644430081,
#  1844505072,
#  1927972279,
#  2022484408,
#  2026352035,
#  2320127002,
#  2347167796,
#  2873212765,
#  2891001357,
#  3372868164,
#  3977333714,
#  4020332650,
#  4057192912,
#  4319703577,
#  4388161847,
#  4445114986,
#  4558609924,
#  4702921684,
#  5553957443,
#  5577150313,
#  6117666160,
#  6290855005,
#  6391747486,
#  6775888955,
#  6962181067,
#  7007744171,
#  7086361926,
#  8053475328,
#  8253242879,
#  8378563200,
#  8583815059,
#  8792009665,
#  8877689391]
